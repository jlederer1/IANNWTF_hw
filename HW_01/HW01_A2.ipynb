# %% [markdown]
# ### HW01_A2

# %%
# %cd /content/drive/My\ Drive/Github/IANNWTF_hw/HW_01
# Out:
# /content/drive/My Drive/Github/IANNWTF_hw/HW_01

# %%
# %ls
# Out:
# HW01_A2.ipynb  IANNwTF_homework01.pdf  kitty.py  __pycache__/  setup.ipynb

# %% [markdown]
# ### A2.1

# %%
import kitty

snowball = kitty.Cat("Snowball")
furrbi = kitty.Cat("Furrbi")

snowball.meow(furrbi)
# Out:
# Hi meow :3
# Hi meow :3
# Hello I am Snowball! I see you are also a cool fluffy kitty Furrbi, let’s together purr at the human, so that they shall give us food

# %% [markdown]
# ### A2.2

# %%
l1 = [x**2 for x in list(range(0,100))]
l2 = [x**2 for x in list(range(0,100)) if (x**2 % 2 == 0)]
l3 = [e for e in l1 if not (e in l2)]
l3;

# %% [markdown]
# ### A2.3

# %%
out = "Meow "
gen = 6
kittygenus = (out*(2**x) for x in range(gen))

for i in range(gen):
  print(next(kittygenus))
# Out:
# Meow
# Meow Meow
# Meow Meow Meow Meow
# Meow Meow Meow Meow Meow Meow Meow Meow
# Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow
# Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow Meow

# %%
import importlib
#importlib.reload(...)

# %% [markdown]
# ### A2.4

# %%
import numpy as np
np.random.seed(42)

n = 5
arr = np.random.standard_normal(size = (n,n))
print(arr)

for i in range(n):
  for j in range(n):
    if arr[i,j] > 0.9 : arr[i,j] **= 2
    else : arr[i,j] = 42

print("\n", arr[:,:4].round(2))
# Out:
# [[ 0.49671415 -0.1382643   0.64768854  1.52302986 -0.23415337]
#  [-0.23413696  1.57921282  0.76743473 -0.46947439  0.54256004]
#  [-0.46341769 -0.46572975  0.24196227 -1.91328024 -1.72491783]
#  [-0.56228753 -1.01283112  0.31424733 -0.90802408 -1.4123037 ]
#  [ 1.46564877 -0.2257763   0.0675282  -1.42474819 -0.54438272]]
#
#  [[42.   42.   42.    2.32]
#  [42.    2.49 42.   42.  ]
#  [42.   42.   42.   42.  ]
#  [42.   42.   42.   42.  ]
#  [ 2.15 42.   42.   42.  ]]

# %% [markdown]
# ### A2.5

# %% [markdown]
# <br/>
# <br/>
#
# ## Answer
# ###### (This is Markdown)
# ###### $(This \: is \: LaTeX)$
# <br/>
#
# ### <font color='red'> $Sigmoid(x)$ </font> $= \frac{1}{1+e^{-x}} = e^x \cdot (1+e^x) $
# ### <font color='red'> $\sigma'(x) \;\;\;\;\;\;\;\;\;\:$ </font> $= \frac{e^x}{e^x+1} = e^x \cdot (1+e^x)^{-1}$
#
# ###### <font color='grey'> &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; u &ensp; $\times$ &emsp;&emsp; v &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; $\to$ Kettenregel</font>
# <br/>
# <br/>
#
# ### $= e^x \cdot (1+e^x)^{-1} + e^x \cdot [(1+e^x)^{-1}]'$
# ###### <font color='grey'> &emsp;&ensp; u' &ensp; $\times$ &emsp;&emsp; v &emsp;&emsp;&emsp;&ensp; + &ensp; u &nbsp; $\times$ &emsp;&emsp;&emsp; v'</font>
# ###### <font color='grey'> &emsp;&ensp; u' &ensp; $\times$ &emsp;&emsp; v &emsp;&emsp;&emsp;&ensp; + &ensp; u &nbsp; $\times$ &emsp;&emsp;&emsp; $[\frac{1}{v}]'$ &emsp;&emsp; &emsp;&emsp;&emsp;&emsp;&emsp;&ensp; $\to$ Reziprokenregel</font>
#
# ### $= e^x \cdot (1+e^x)^{-1} + e^x \cdot $ <font color='blue'> $-([1+e^x]'/(1+e^x)^2)$ </font>
#
# ###### <font color='grey'> &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; $-\frac{v'}{v^2}$ </font>
#
# ### $=$ &emsp;&emsp; $\frac{e^x}{1+e^x} \;\;\;\;\;\;\;\; - \;\;\;\;\;\;\;\;\;\;\;\;\;\;\;$  <font color='blue'> $\frac{e^{2x}}{1+2e^x+e^{2x}}$ </font>
#
# ### $=$ &emsp;&emsp; $\frac{e^x}{1+e^x} \;\;\;\;\;\;\;\; - \;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;$  <font color='blue'> $(\frac{e^x}{1+e^x})^2$ </font>
#
# ### $=$ <font color='red'> &emsp;&emsp; $Sigmoid(x) - Sigmoid(x)^2 $ </font>
# ### $=$ <font color='red'> &emsp;&emsp; $\underline {\sigma(x) \cdot (1-\sigma(x))} $ </font>

# %% [markdown]
# Der Nabla-Operator ist ein Symbol, das in der Vektor- und Tensoranalysis benutzt wird, um kontextabhängig einen der drei Differentialoperatoren Gradient, Divergenz oder Rotation zu notieren. Das Formelzeichen des Operators ist das Nabla-Symbol. Im Englischen wird der Operator als „del“ bezeichnet.

# %% [markdown]
# ![Nabla-Gradienten-vektor.png](data:image/png;base64,...)

# %% [markdown]
# Partial derivatives of : $f(x, z, a, b) := y = (4ax^2 + a) + 3 + \sigma(z) + (\sigma(b)^2)$

# %% [markdown]
# $f\frac{\partial}{\partial x} = 8ax$ </br></br>
# $f\frac{\partial}{\partial z} = \sigma(z) \cdot (1-\sigma(z))$ </br></br>
# $f\frac{\partial}{\partial a} = 4x^2+1$ </br></br>
# $f\frac{\partial}{\partial b} = [\sigma(b)^2]' = [(\frac{1}{(1+e^{-b})^2})]'$ </br></br>
# <font color='grey'>$ \;\;\;\;\;\;\; = \frac{\partial}{\partial u}[\frac{1}{u^2}]\frac{\partial}{\partial b} = \frac{\partial}{\partial u} [u^{-3}]\frac{\partial u}{\partial b}=[-\frac{2}{u^3}]\frac{\partial u}{\partial b} = -\frac{2 \cdot \frac{\partial}{\partial b}[u]}{u^3} \;\;\;\;\;\;\;\;|u = (1+e^{-b})$</font> </br></br>
#
# $\;\;\;\;\;\;\;=-\frac{2 \cdot \frac{\partial}{\partial b}(1+e^{-b})}{(1+e^{-b})^3} = -\frac{2}{(1+e^{-b})^3} \cdot (\frac{\partial}{\partial b}[1] + \frac{\partial}{\partial b}[e^{-b}])$ </br></br>
#
# $\;\;\;\;\;\;\; = -\frac{2}{(1+e^{-b})^3} \cdot (\frac{\partial}{\partial b}[e^{-b}])$ <font color='grey'> $ = -\frac{2}{(1+e^{-b})^3} \cdot (\frac{\partial e^{u}}{\partial u} \cdot \frac{\partial u}{\partial b})\;\;\;\;\;\;\;\;\;\;\; | u = (-b)$ </font> </br></br>
#
# <font color='grey'> $\;\;\;\;\;\;\; = -\frac{2}{(1+e^{-b})^3} \cdot (e^{u} \cdot -1)$ </font> </br></br>
#
# $\;\;\;\;\;\;\; = -\frac{2}{(1+e^{-b})^3} \cdot (-e^{-b})$  </br></br>
#
# $\;\;\;\;\;\;\; = \underline{ \frac{2e^{-b}}{(1+e^{-b})^3} }$
