# %% [markdown]
# ### [COLAB, GitHub and Drive](https://medium.com/analytics-vidhya/how-to-use-google-colab-with-github-via-google-drive-68efb23a42d)

# %% [markdown]
# #### COLAB
# *   Terminal access
# *   Git Repo init'

# %%
# %cd /content/drive/MyDrive/Github/
# %ls
# Out:
# /content/drive/MyDrive/Github
# IANNWTF_hw/

# %%
#     #!git init IANNWTF_hw
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Github/IANNWTF_hw/.git/

# %%
# %ls 
# %cd IANNWTF_hw
# %ls -a
# Out:
# IANNWTF_hw/
# /content/drive/MyDrive/Github/IANNWTF_hw
# .git/  HW_01/  .ipynb_checkpoints/

# %% [markdown]
# #### GitHub
# *   GitHub config'
# *   Git Repo staging

# %%
# !git config --global user.email "jlederer@uni-osnabrueck.de" 
# !git config --global user.name "jlederer1"

# %%
# !git status
# Out:
# On branch working
# Your branch is up to date with 'origin/working'.
#
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	modified:   HW_01/setup.ipynb

# %%
# !git add .

# %%
#     #!git commit -m "[HW01.v0] Added : IANNwTF_homework01.pdf, setup.ipynb"
# Out:
# [master (root-commit) dba2f6b] [HW01.v0] Added : IANNwTF_homework01.pdf, setup.ipynb
#  2 files changed, 1 insertion(+)
#  create mode 100644 HW_01/IANNwTF_homework01.pdf
#  create mode 100644 HW_01/setup.ipynb

# %% [markdown]
# #### Google Drive git repo config & push
# Credentials, git remote, push
#
# *   Credentials, Git remote access
# *   Git share & update

# %%
username = 'jlederer1'
repository = 'IANNWTF_hw'
git_token = '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' #PAT-id : "IANNWTF"

# !git remote add origin https://{git_token}@github.com/{username}/{repository}.git
# !git remote -v
# Out:
# fatal: remote origin already exists.
# origin	https://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@github.com/jlederer1/IANNWTF_hw.git (fetch)
# origin	https://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@github.com/jlederer1/IANNWTF_hw.git (push)

# %%
#     #!git push -u origin master
# Out:
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (5/5), 254.07 KiB | 10.59 MiB/s, done.
# Total 5 (delta 0), reused 0 (delta 0)
# To https://github.com/jlederer1/IANNWTF_hw.git
#  * [new branch]      master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %% [markdown]
# ### Branches
# *   Git branch & merge
# *   Git remote access reconfiguration

# %%
# !git branch
# Out:
#   master
# * working

# %%
#     #!git branch working

# %%
# !git checkout master
# Out:
# error: Your local changes to the following files would be overwritten by checkout:
# 	HW_01/setup.ipynb
# Please commit your changes or stash them before you switch branches.
# Aborting

# %%
# !git log
# Out:
# commit ecbe5bca2fc790b494f7e9253175f87693c6ec8d (HEAD -> working, origin/working)
# Author: jlederer1 <jlederer@uni-osnabrueck.de>
# Date:   Thu Nov 3 17:08:22 2022 +0000
#
#     [HW01.v0.1] Edit : setup.ipynb -> Cleaned, Merging branches
#
# commit 62ae53085c281dfd7c7daa17fca898a7082ce832
# Author: jlederer1 <jlederer@uni-osnabrueck.de>
# Date:   Thu Nov 3 15:20:19 2022 +0000
#
#     [HW01.v0.0] Edit : setup.ipynb -> Organisational, First working branch
#
# commit dba2f6be41f043f155134dd9bb51a67912b36967 (origin/master, master)
# Author: jlederer1 <jlederer@uni-osnabrueck.de>
# Date:   Thu Nov 3 14:37:28 2022 +0000
#
#     [HW01.v0] Added : IANNwTF_homework01.pdf, setup.ipynb

# %%
# !git commit -m "[HW01.v0.0] Edit : setup.ipynb -> Organisational, First working branch"
# Out:
# [working 62ae530] [HW01.v0.0] Edit : setup.ipynb -> Organisational, First working branch
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite HW_01/setup.ipynb (97%)

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/jlederer1/IANNWTF_hw.git (fetch)
# origin	https://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@github.com/jlederer1/IANNWTF_hw.git (push)

# %%
#####!git push -u origin working
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %%
print(username, repository, git_token)
print("https://{git_token}@github.com/{username}/{repository}.git")
# !git remote -v
# Out:
# jlederer1 IANNWTF_hw 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
# https://{git_token}@github.com/{username}/{repository}.git
# origin	https://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@github.com/jlederer1/IANNWTF_hw.git (fetch)
# origin	https://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@github.com/jlederer1/IANNWTF_hw.git (push)

# %%
######!git remote set-url origin https://{git_token}@github.com/{username}/{repository}.git

# %%
#     #!git push -u origin working
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (4/4), 2.02 KiB | 344.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# remote:
# remote: Create a pull request for 'working' on GitHub by visiting:
# remote:      https://github.com/jlederer1/IANNWTF_hw/pull/new/working
# remote:
# To https://github.com/jlederer1/IANNWTF_hw.git
#  * [new branch]      working -> working
# Branch 'working' set up to track remote branch 'working' from 'origin'.

# %% [markdown]
# -> Releasing stable (first) working branch

# %%
#####!git commit -m "[HW01.v0.1] Edit : setup.ipynb -> Cleaned, Merging branches"
#   #!git push -u origin working
# Out:
# [working ecbe5bc] [HW01.v0.1] Edit : setup.ipynb -> Cleaned, Merging branches
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite HW_01/setup.ipynb (98%)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (4/4), 2.18 KiB | 372.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/jlederer1/IANNWTF_hw.git
#    62ae530..ecbe5bc  working -> working
# Branch 'working' set up to track remote branch 'working' from 'origin'.

# %% [markdown]
# --> Merging working branch into master

# %%
# !git commit -m "[HW01.v1.0] Edit : setup.ipynb -> Cleaned, Merging branches"
# !git merge working -m "[HW01.v1] Merge : v0.1 -> v1"
